# %% [markdown]
# <a href="https://colab.research.google.com/github/uzmaamjadseecs/Custom-LLM-from-scratch-/blob/main/RiskPolicyChatBot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pdfplumber -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 72.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 93.1 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')

# Point these at your actual folders in Drive
PDF_DIR = "/content/drive/MyDrive/Risk Policy Chatbot/"      # folder with your 34 PDFs
OUT_DIR = "/content/drive/MyDrive/cleaned_output/"   # where results go

import os
os.makedirs(OUT_DIR, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
PDF_DIR
# Out:
# '/content/drive/MyDrive/Risk Policy Chatbot/'

# %%
print(f"Files in PDF_DIR ({PDF_DIR}):")
for file in os.listdir(PDF_DIR):
    print(f"- {file}")
# Out:
# Files in PDF_DIR (/content/drive/MyDrive/Risk Policy Chatbot/):
# - CAU Manual MMBL.pdf
# - Credit Operation Manual Version 3 (March 2023) Final.pdf
# - Product Manual - Karobar Plus Loan - V2 (Signed) October 2025.pdf
# - LAM 01 Sep 23-a.pdf
# - Credit_Policy_V3.pdf

# %%
print(f"Files in PDF_DIR ({OUT_DIR}):")
for file in os.listdir(OUT_DIR):
    print(f"- {file}")
# Out:
# Files in PDF_DIR (/content/drive/MyDrive/cleaned_output/):
